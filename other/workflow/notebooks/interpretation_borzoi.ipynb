# %%
import matplotlib.pyplot as plt
import pandas as pd
import polars as pl
import seaborn as sns
from tqdm import tqdm
import warnings
warnings.filterwarnings("ignore")

# %%
subset_renaming = {
    "600886": "Hyperferritinemia",
    "613985": "Beta-thalassemia",
    "614743": "Pulmonary fibrosis",
    "306900": "Hemophilia B",
    "250250": "Cartilage-hair hypoplasia",
    "174500": "Preaxial polydactyly II",
    "143890": "Hypercholesterolemia-1",
    "210710": "Dwarfism (MOPD1)",

    "Mono": "Monocyte count",
    "HbA1c": "Hemoglobin A1c",
    "HDLC": "High density lipoprotein cholesterol",
}

# %%
borzoi_metadata = pd.read_csv(
    "../../results/metadata/Borzoi.csv", usecols=["name", "description", "assay", "sample"]
)
borzoi_metadata
# Out:
#                             name  \
# 0                     CNhs10608+
# 1                     CNhs10608-
# 2                     CNhs10610+
# 3                     CNhs10610-
# 4                     CNhs10612+
# ...                          ...
# 7606  GTEX-13FTX-1026-SM-5J2O5.1
# 7607  GTEX-1MA7W-1526-SM-DHXKS.1
# 7608  GTEX-11EMC-1926-SM-5A5JU.1
# 7609  GTEX-12WSB-2426-SM-5EGJC.1
# 7610   GTEX-W5WG-1026-SM-4LMIF.1
#
#                                             description assay  \
# 0     CAGE:Clontech Human Universal Reference Total ...  CAGE
# 1     CAGE:Clontech Human Universal Reference Total ...  CAGE
# 2     CAGE:SABiosciences XpressRef Human Universal T...  CAGE
# 3     CAGE:SABiosciences XpressRef Human Universal T...  CAGE
# 4     CAGE:Universal RNA - Human Normal Tissues Bioc...  CAGE
# ...                                                 ...   ...
# 7606                                         RNA:uterus   RNA
# 7607                                         RNA:uterus   RNA
# 7608                                         RNA:vagina   RNA
# 7609                                         RNA:vagina   RNA
# 7610                                         RNA:vagina   RNA
#
#                                                  sample
# 0     Clontech Human Universal Reference Total RNA, ...
# 1     Clontech Human Universal Reference Total RNA, ...
# 2     SABiosciences XpressRef Human Universal Total ...
# 3     SABiosciences XpressRef Human Universal Total ...
# 4     Universal RNA - Human Normal Tissues Biochain,...
# ...                                                 ...
# 7606                                             uterus
# 7607                                             uterus
# 7608                                             vagina
# 7609                                             vagina
# 7610                                             vagina
#
# [7611 rows x 4 columns]

# %%
#dataset = "mendelian_traits_matched_9"
#subsets = [
#    "613985",  # Beta-thalassemia
#    #"614743",
#    "306900",  # Hemophilia B
#    #"250250",
#    "143890",  # Hypercholesterolemia-1
#]

dataset = "complex_traits_matched_9"
subsets = [
    "Mono",
    "HbA1c",
    "HDLC",
    ##"Alb",
    ##"DVT",
]

base_dir = f"../../results/dataset/{dataset}"
V = pd.read_parquet(f"{base_dir}/test.parquet")

# %% [markdown]
# ## Marginal performance

# %%
models = pd.DataFrame(
    [
        ["Borzoi", "Borzoi_L2", "C1"],
    ],
    columns=["Model", "path", "color"]
).set_index("Model")
models
# Out:
#              path color
# Model
# Borzoi  Borzoi_L2    C1

# %%
dfs = []
sample_size = {}

for subset in tqdm(subsets):
    s = pd.read_parquet(f"{base_dir}/subset/{subset}.parquet")
    V_s = s.merge(V, on=["chrom", "pos", "ref", "alt"], how="left")
    sample_size[subset] = V_s.label.sum(), (~V_s.label).sum()
    for model in models.index:
        df = pd.read_csv(f"{base_dir}/unsupervised_metrics/{subset}/{models.loc[model, 'path']}.csv")
        df = df.merge(borzoi_metadata, left_on="feature", right_on="name", how="inner")
        #df = df[df.assay.isin(["RNA", "CAGE"])]
        df = df.drop_duplicates("sample")
        df = df.head(50)
        df["subset"] = subset_renaming.get(subset, subset)
        df["Model"] = model
        dfs.append(df)
df = pd.concat(dfs)
df
# Out:
# 100%|██████████████████████████████████████████████| 3/3 [00:00<00:00, 28.03it/s]
#        AUPRC      feature  sign         name  \
# 0   0.559428  ENCFF909JRL  plus  ENCFF909JRL
# 1   0.559420   CNhs13543-  plus   CNhs13543-
# 2   0.559317  ENCFF634ZUJ  plus  ENCFF634ZUJ
# 3   0.556510   CNhs13544-  plus   CNhs13544-
# 4   0.555901   CNhs11959-  plus   CNhs11959-
# ..       ...          ...   ...          ...
# 45  0.386305        kai17  plus        kai17
# 46  0.386263  ENCFF869EBO  plus  ENCFF869EBO
# 47  0.386036        kai41  plus        kai41
# 48  0.385797       kai158  plus       kai158
# 49  0.384957  ENCFF669BCZ  plus  ENCFF669BCZ
#
#                                           description  assay  \
# 0                             CHIP:H3K27ac:neutrophil   CHIP
# 1            CAGE:CD14+ monocytes - treated with BCG,   CAGE
# 2                                         DNASE:HL-60  DNASE
# 3   CAGE:CD14+ monocytes - treated with Trehalose ...   CAGE
# 4                                   CAGE:Neutrophils,   CAGE
# ..                                                ...    ...
# 45                            ATAC:Cardiac Pericyte 1   ATAC
# 46            CHIP:NR2F2:liver female child (4 years)   CHIP
# 47                                   ATAC:Fasciculata   ATAC
# 48                                   ATAC:Fibro Nerve   ATAC
# 49           CHIP:H3K4me3:liver male adult (78 years)   CHIP
#
#                                                sample  \
# 0                                  H3K27ac:neutrophil
# 1                 CD14+ monocytes - treated with BCG,
# 2                                               HL-60
# 3   CD14+ monocytes - treated with Trehalose dimyc...
# 4                                        Neutrophils,
# ..                                                ...
# 45                                 Cardiac Pericyte 1
# 46                 NR2F2:liver female child (4 years)
# 47                                        Fasciculata
# 48                                        Fibro Nerve
# 49                H3K4me3:liver male adult (78 years)
#
#                                   subset   Model
# 0                         Monocyte count  Borzoi
# 1                         Monocyte count  Borzoi
# 2                         Monocyte count  Borzoi
# 3                         Monocyte count  Borzoi
# 4                         Monocyte count  Borzoi
# ..                                   ...     ...
# 45  High density lipoprotein cholesterol  Borzoi
# 46  High density lipoprotein cholesterol  Borzoi
# 47  High density lipoprotein cholesterol  Borzoi
# 48  High density lipoprotein cholesterol  Borzoi
# 49  High density lipoprotein cholesterol  Borzoi
#
# [150 rows x 9 columns]

# %%
for subset in df.subset.unique():
    print(subset)
    df2 = df[df.subset==subset]
    print(df2[["AUPRC", "sample"]].values)
# Out:
# Monocyte count
# [[0.5594275679632358 'H3K27ac:neutrophil']
#  [0.5594197731790993 'CD14+ monocytes - treated with BCG,']
#  [0.5593168759372902 'HL-60']
#  [0.5565096595616823
#   'CD14+ monocytes - treated with Trehalose dimycolate (TDM),']
#  [0.5559008678844445 'Neutrophils,']
#  [0.5547687078340207
#   'CD14+ monocytes - treated with Group A streptococci,']
#  [0.5539842593614636 'CD14+ monocytes - treated with Candida,']
#  [0.551645784835633 'CD14-positive monocyte female']
#  [0.5513570010354896 'CD14+ Monocytes,']
#  [0.5509086358972433 'CD14+ monocytes - treated with Salmonella,']
#  [0.5493412296336347 'CD14-positive monocyte female adult (34 years)']
#  [0.5472064606151904 'CD14+ monocytes - treated with lipopolysaccharide,']
#  [0.5459859946116948 'CD14+ monocytes - treated with Cryptococcus,']
#  [0.5449150549395325 'CD14-positive monocyte male adult (21 year)']
#  [0.5442359008530452 'CD14-positive monocyte male adult (37 years)']
#  [0.5442307897286576 'CD14+ monocytes - treated with B-glucan,']
#  [0.54213111514947 'CD14+CD16+ Monocytes,']
#  [0.5415184948087098 'CD14+ monocytes - treated with IFN + N-hexane,']
#  [0.537370662715275 'H3K27ac:CD14-positive monocyte female']
#  [0.5360903428661044 'H3K4me1:neutrophil']
#  [0.5359236596332505 'CD14+CD16- Monocytes,']
#  [0.5345085527558937 'CD14+ monocytes - mock treated,']
#  [0.5340948823857062 'H3K9ac:CD14-positive monocyte female']
#  [0.532125982629423 'H3K27ac:CD14-positive monocyte male adult (21 year)']
#  [0.5320478155467838 'H3K4me1:neutrophil male']
#  [0.5315993717793783 'Basophils,']
#  [0.5306013198418855 'Eosinophils,']
#  [0.5255014454528923 'NB4']
#  [0.5252345884517514 'CD14-CD16+ Monocytes,']
#  [0.520739975383624 'H3K79me2:CD14-positive monocyte female']
#  [0.5187405457690281 'H3K4me3:neutrophil']
#  [0.5181708250807681 'BM0106-UNK-ATAC-2 / Bone Marrow CD34+ / UNK']
#  [0.514971344741618 'BM1214-Day0-UNK-A / Bone Marrow CD34+ / UNK']
#  [0.5135122422383923 'Peripheral Blood Mononuclear Cells,']
#  [0.5131483640041076 'CD1c-positive myeloid dendritic cell']
#  [0.5104355739986721 'BM1137-GMP1-low-ATAC-2 / Bone Marrow CD34+ / GMP-A']
#  [0.5047037877227679 'H3K4me3:neutrophil male']
#  [0.5036575221335231 'BM1137-GMP2-mid-ATAC-1 / Bone Marrow CD34+ / GMP-B']
#  [0.5022427181063056 'BM1077-UNK / Bone Marrow CD34+ / UNK']
#  [0.5017474464453503 'with multiple sclerosis; CD14-positive monocyte']
#  [0.5007159182355717 'KBM-7']
#  [0.5005550524511823 'CD14-positive monocyte']
#  [0.4959639394785443 'H3K27ac:spleen male adult (34 years)']
#  [0.4884472724477535 'H3K4me3:CD14-positive monocyte female']
#  [0.4855847650528718
#   'H3K36me3:CD14-positive monocyte male adult (21 year)']
#  [0.483677249577053 'H3K36me3:CD14-positive monocyte female']
#  [0.4829370877612209 'POLR2AphosphoS5:HL-60']
#  [0.4812557219057823 'common myeloid progenitor, CD34-positive male']
#  [0.4808833321745096 'mononuclear cell female adult (52 years)']
#  [0.479978165723643
#   'hematopoietic multipotent progenitor cell treated with interleukin-3 for 4 days, kit ligand for 4 days, hydrocortisone succinate for 4 days, erythropoietin for 4 days']]
# Hemoglobin A1c
# [[0.4487659401317565 'H3K9ac:K562']
#  [0.4394329075102384 'K562 treated with Interferon gamma for 6 hours']
#  [0.4331729654373552 'RBFOX2:K562']
#  [0.4308217207984071 'K562 treated with interferon alpha for 6 hours']
#  [0.4253284287128007 'K562 treated with interferon alpha for 30 minutes']
#  [0.4230357157155006 'Fetal Erythroblast 5']
#  [0.4229007435389404 'K562 treated with Interferon gamma for 30 minutes']
#  [0.4225636230045351
#   'POLR2A:K562 treated with interferon gamma for 6 hours']
#  [0.4209591078077486 'H3K4me3:K562']
#  [0.4202969225375734 'POLR2G:K562']
#  [0.4185824586355559
#   'POLR2A:K562 treated with interferon gamma for 30 minutes']
#  [0.4148977072048215
#   'hematopoietic multipotent progenitor cell treated with interleukin-3 for 13 days, kit ligand for 13 days, hydrocortisone succinate for 13 days, erythropoietin for 13 days']
#  [0.4117853172462982
#   'POLR2A:K562 treated with interferon alpha for 30 minutes']
#  [0.4110365568623522 'H3K79me2:K562']
#  [0.4109712938689141
#   'hematopoietic multipotent progenitor cell treated with interleukin-3 for 15 days, kit ligand for 15 days, hydrocortisone succinate for 15 days, erythropoietin for 15 days']
#  [0.4103139552600768
#   'POLR2A:K562 treated with interferon alpha for 6 hours']
#  [0.4087571530997907 'POLR2A:K562']
#  [0.4081673483392058
#   'hematopoietic multipotent progenitor cell treated with interleukin-3 for 17 days, kit ligand for 17 days, hydrocortisone succinate for 17 days, erythropoietin for 17 days']
#  [0.4080504628020791 'K562 nuclear fraction']
#  [0.4064722668189445
#   'hematopoietic multipotent progenitor cell male adult (25 years) treated with erythropoietin for 20 days, hydrocortisone succinate for 20 days, kit ligand for 20 days, interleukin-3 for 20 days']
#  [0.4053243150929062 'Fetal Erythroblast 4']
#  [0.4043703347034474 'K562 chromatin fraction']
#  [0.4043125797751514 'K562 nucleolus fraction']
#  [0.4035650420814568 'H3K4me2:K562']
#  [0.4021218066415599 'K562']
#  [0.4008650603210001 'K562 treated with 50 uM C646 for 12 hours']
#  [0.4004988469775384 'K562 nucleoplasmic fraction']
#  [0.4002616769190584 'H2AFZ:K562']
#  [0.3997611512015437
#   'hematopoietic multipotent progenitor cell treated with interleukin-3 for 18 days, kit ligand for 18 days, hydrocortisone succinate for 18 days, erythropoietin for 18 days']
#  [0.3994675481565806 'K562 treated with 50 uM C646 for 24 hours']
#  [0.3976300438750199 'PHF8:K562']
#  [0.397616878656578 'bone_marrow']
#  [0.3975622408572955 'liver embryo (59 days) and embryo (80 days)']
#  [0.3968289484734333 'RBBP5:K562']
#  [0.3962551872021315 'POLR2AphosphoS5:K562']
#  [0.3940150557284918
#   'hematopoietic multipotent progenitor cell treated with interleukin-3 for 11 day, kit ligand for 11 day, hydrocortisone succinate for 11 day, erythropoietin for 11 day']
#  [0.3922688350724181 'Fetal Endothelial Hepatic 2']
#  [0.3917739778558382 'K562 membrane fraction']
#  [0.3916723828759383 'K562 cytosolic fraction']
#  [0.3913044953695714 'TBP:K562']
#  [0.3895017911785635 'H3K36me3:K562']
#  [0.3878870559860438 'H3K27ac:CD8-positive, alpha-beta memory T cell']
#  [0.38612422437854 'K562 treated with 100 nM GSK J4 for 24 hours']
#  [0.3860273861803152 'MYC:K562 treated with interferon gamma for 6 hours']
#  [0.3858613240227602 'ZNF592:K562']
#  [0.3850395025563626 'K562 treated with 5 uM JQ1 for 4 hours']
#  [0.3847403074369308 'K562 treated with 100 nM GSK J4 for 4 hours']
#  [0.3832980585612458 'K562 treated with 50 uM C646 for 4 hours']
#  [0.3830342251947462 'K562 treated with 5 uM MB-3 for 24 hours']
#  [0.3814798867596706 'POLR2AphosphoS2:K562']]
# High density lipoprotein cholesterol
# [[0.440237937309374 'JUND:liver male adult (32 years)']
#  [0.4334346769712581 'JUND:liver female child (4 years)']
#  [0.4314188112703624 'RXRA:liver male adult (32 years)']
#  [0.4307472622108473 'ZBTB33:liver male adult (32 years)']
#  [0.4297859850899853 'EGR1:liver male adult (32 years)']
#  [0.4292391222863201 'H3K9ac:liver male adult (31 year)']
#  [0.4291917993456397 'ATF3:liver male adult (32 years)']
#  [0.4283463279658339 'H3K27ac:liver female adult (25 years)']
#  [0.4282021580938562 'SP1:liver female child (4 years)']
#  [0.4267458921673835 'H3K9ac:liver female adult (25 years)']
#  [0.4232474690603495 'RXRA:liver female child (4 years)']
#  [0.4227949105569293 'MAX:liver male adult (32 years)']
#  [0.4200743832793233 'SP1:liver male adult (32 years)']
#  [0.4196005061813765
#   'H3K9ac:subcutaneous abdominal adipose tissue nuclear fraction female adult (49 years)']
#  [0.4183060068023829 'POLR2A:right lobe of liver female adult (53 years)']
#  [0.4168708569384859 'H3K27ac:adrenal gland male adult (37 years)']
#  [0.4153646003125265 'YY1:liver female child (4 years)']
#  [0.4142310892509139 'H3K27ac:liver male adult (31 year)']
#  [0.410771716600224 'MAX:liver female child (4 years)']
#  [0.4091730328900471 'H3K27ac:heart left ventricle male adult (32 years)']
#  [0.4076541893824109 'YY1:liver male adult (32 years)']
#  [0.407345065202656 'GABPA:liver male adult (32 years)']
#  [0.4066347843021251 'H3K27ac:adrenal gland male adult (54 years)']
#  [0.4046430195704724 'Pericyte General 1']
#  [0.4038652532648753 'REST:liver male adult (32 years)']
#  [0.4037909974385874
#   'H3K27ac:right lobe of liver female adult (53 years)']
#  [0.4036199898517575 'REST:liver female child (4 years)']
#  [0.4028714866450366
#   'H3K9ac:subcutaneous abdominal adipose tissue nuclear fraction female adult (25 years)']
#  [0.3994319184815906 'H3K4me1:breast epithelium female adult (53 years)']
#  [0.3991865821806229 'FOXA2:HepG2']
#  [0.3988151919506753 'EGR1:liver female child (4 years)']
#  [0.3983305640047985 'Hepatocyte']
#  [0.3976034734789013 'NR2F2:liver male adult (32 years)']
#  [0.3975882655743238
#   'H3K9ac:subcutaneous abdominal adipose tissue nuclear fraction female adult (41 year)']
#  [0.3973023312618257 'ATF3:liver female child (4 years)']
#  [0.3965262023460243
#   'H3K27ac:subcutaneous abdominal adipose tissue nuclear fraction female adult (49 years)']
#  [0.3964619242467137 'Pericyte General 3']
#  [0.3962687065224666 'Fibro Muscle']
#  [0.3946890455189631 'FOXA2:liver male adult (32 years)']
#  [0.390908573295256 'FOXA2:liver female child (4 years)']
#  [0.3902355593347137
#   'H3K4me3:right lobe of liver female adult (53 years)']
#  [0.389955211778385
#   'GR:ChIP-seq, GR_HighDensity_DMI / hMSC / Human Mesenchymal Stem Cells']
#  [0.3890799393925165
#   'H3K4me1:subcutaneous abdominal adipose tissue nuclear fraction female adult (49 years)']
#  [0.3872458051619077 'lower leg skin female adult (53 years)']
#  [0.3871352574660675 'EP300:tibial nerve female adult (51 year)']
#  [0.3863051710131418 'Cardiac Pericyte 1']
#  [0.3862626173846668 'NR2F2:liver female child (4 years)']
#  [0.3860364484041042 'Fasciculata']
#  [0.3857968051466411 'Fibro Nerve']
#  [0.3849572990713505 'H3K4me3:liver male adult (78 years)']]
