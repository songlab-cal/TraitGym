# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
model_metadata = pd.read_csv("../../config/models.csv")
palette = model_metadata.set_index("description")["color"].to_dict()
model_renaming = model_metadata.set_index("name")["description"].to_dict()
model_metadata
# Out:
#                      name   description color
# 0                    CADD          CADD    C0
# 1                 GPN-MSA       GPN-MSA    C1
# 2                  Borzoi        Borzoi    C2
# 3                Enformer      Enformer    C3
# 4                     GPN  gLM-Promoter    C4
# 5   NucleotideTransformer            NT    C5
# 6                HyenaDNA      HyenaDNA    C6
# 7                Caduceus      Caduceus    C7
# 8     CADD+GPN-MSA+Borzoi      Ensemble    C8
# 9                     Sei           Sei    C9
# 10              GPN_final  gLM-Promoter    C4

# %%
dataset_renaming = {
}

subset_renaming = {
    "all": "Complex traits\nPIP > 0.9 (1140 positives)",
    "pip_0.99": "Complex traits\nPIP > 0.99 (749 positives)",
    "pip_0.999": "Complex traits\nPIP > 0.999 (535 positives)",
}

# %%
datasets = [
    "complex_traits_matched_9",
]

subsets = [
    "all",
    "pip_0.99",
    "pip_0.999",
]

modalities = [
    "Zero-shot",
    "Linear probing",
]

models = [
    "CADD",
    "GPN-MSA",
    "Borzoi",
]

model_zero_shot_score = {
    "CADD": "CADD.plus.RawScore",
    "Borzoi": "Borzoi_L2_L2.plus.all",
    "GPN-MSA": "GPN-MSA_absLLR.plus.score",
}

metric = "AUPRC"

def get_model_path(model, modality, dataset, subset, metric):
    if modality == "Linear probing":
        if subset == "all":
            predictor = f"{model}.LogisticRegression.chrom"
        else:
            predictor = f"{model}.LogisticRegression.chrom.subset_from_all"
    elif modality == "Zero-shot":
        predictor = model_zero_shot_score[model]
    return f"../../results/dataset/{dataset}/{metric}_by_chrom_weighted_average/{subset}/{predictor}.csv"

# %%
rows = []
for dataset in datasets:
    for subset in subsets:
        for modality in modalities:
            for model in models:
                path = get_model_path(model, modality, dataset, subset, metric)
                df = pd.read_csv(path).iloc[0]
                rows.append([
                    dataset_renaming.get(dataset, dataset),
                    subset_renaming.get(subset, subset),
                    modality,
                    model_renaming.get(model, model),
                    df["score"],
                    df["se"]]
                )
df = pd.DataFrame(rows, columns=["dataset", "subset", "modality", "model", metric, "se"])
df
# Out:
#                      dataset                                       subset  \
# 0   complex_traits_matched_9   Complex traits\nPIP > 0.9 (1140 positives)
# 1   complex_traits_matched_9   Complex traits\nPIP > 0.9 (1140 positives)
# 2   complex_traits_matched_9   Complex traits\nPIP > 0.9 (1140 positives)
# 3   complex_traits_matched_9   Complex traits\nPIP > 0.9 (1140 positives)
# 4   complex_traits_matched_9   Complex traits\nPIP > 0.9 (1140 positives)
# 5   complex_traits_matched_9   Complex traits\nPIP > 0.9 (1140 positives)
# 6   complex_traits_matched_9   Complex traits\nPIP > 0.99 (749 positives)
# 7   complex_traits_matched_9   Complex traits\nPIP > 0.99 (749 positives)
# 8   complex_traits_matched_9   Complex traits\nPIP > 0.99 (749 positives)
# 9   complex_traits_matched_9   Complex traits\nPIP > 0.99 (749 positives)
# 10  complex_traits_matched_9   Complex traits\nPIP > 0.99 (749 positives)
# 11  complex_traits_matched_9   Complex traits\nPIP > 0.99 (749 positives)
# 12  complex_traits_matched_9  Complex traits\nPIP > 0.999 (535 positives)
# 13  complex_traits_matched_9  Complex traits\nPIP > 0.999 (535 positives)
# 14  complex_traits_matched_9  Complex traits\nPIP > 0.999 (535 positives)
# 15  complex_traits_matched_9  Complex traits\nPIP > 0.999 (535 positives)
# 16  complex_traits_matched_9  Complex traits\nPIP > 0.999 (535 positives)
# 17  complex_traits_matched_9  Complex traits\nPIP > 0.999 (535 positives)
#
#           modality    model     AUPRC        se
# 0        Zero-shot     CADD  0.249900  0.010183
# 1        Zero-shot  GPN-MSA  0.223643  0.009396
# 2        Zero-shot   Borzoi  0.235739  0.009155
# 3   Linear probing     CADD  0.283858  0.012406
# 4   Linear probing  GPN-MSA  0.269382  0.011520
# 5   Linear probing   Borzoi  0.296688  0.014071
# 6        Zero-shot     CADD  0.260520  0.010740
# 7        Zero-shot  GPN-MSA  0.234295  0.008994
# 8        Zero-shot   Borzoi  0.271707  0.012833
# 9   Linear probing     CADD  0.296939  0.012849
# 10  Linear probing  GPN-MSA  0.291977  0.010263
# 11  Linear probing   Borzoi  0.330975  0.017462
# 12       Zero-shot     CADD  0.283860  0.010994
# 13       Zero-shot  GPN-MSA  0.252258  0.011245
# 14       Zero-shot   Borzoi  0.301053  0.016865
# 15  Linear probing     CADD  0.319983  0.015982
# 16  Linear probing  GPN-MSA  0.309936  0.013992
# 17  Linear probing   Borzoi  0.362752  0.020206

# %%
def plot():
    df_s = df

    g = sns.FacetGrid(
        df_s,
        col="subset",
        row="modality",
        margin_titles=True,
        sharex="col",
        sharey=False,#"row",
        height=2.2,
        aspect=1.35,
    )

    def my_boxplot(data, **kwargs):
        data = data.sort_values(metric, ascending=False)
        ax = plt.gca()
        g = sns.barplot(
            data=data,
            y="model",
            x=metric,
            ax=ax,
            palette=palette,
            #showfliers=False, whis=0, # optional
        )
        ax.errorbar(
            x=data[metric],
            y=data["model"],
            xerr=data["se"],
            fmt='none',      # Do not add markers (those are already in the pointplot)
            color="black",
        )

    g.map_dataframe(my_boxplot)

    g.set(
        ylabel="",
        xlim=0.1 if metric == "AUPRC" else 0.5,
    )
    g.set_titles(
        col_template="{col_name}", row_template="{row_name}",
        fontweight="bold",
        size=12,
    )
    g.tight_layout()
    plt.savefig(f"../../results/plots/performance_pip_ablation.pdf", bbox_inches="tight")

# %%
plot()
# Out:
# /scratch/users/gbenegas/software/mambaforge/envs/gpn/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /scratch/users/gbenegas/software/mambaforge/envs/gpn/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /scratch/users/gbenegas/software/mambaforge/envs/gpn/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /scratch/users/gbenegas/software/mambaforge/envs/gpn/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /scratch/users/gbenegas/software/mambaforge/envs/gpn/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /scratch/users/gbenegas/software/mambaforge/envs/gpn/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /scratch/users/gbenegas/software/mambaforge/envs/gpn/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /scratch/users/gbenegas/software/mambaforge/envs/gpn/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /scratch/users/gbenegas/software/mambaforge/envs/gpn/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /scratch/users/gbenegas/software/mambaforge/envs/gpn/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /scratch/users/gbenegas/software/mambaforge/envs/gpn/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /scratch/users/gbenegas/software/mambaforge/envs/gpn/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /scratch/users/gbenegas/software/mambaforge/envs/gpn/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /scratch/users/gbenegas/software/mambaforge/envs/gpn/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /scratch/users/gbenegas/software/mambaforge/envs/gpn/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /scratch/users/gbenegas/software/mambaforge/envs/gpn/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /scratch/users/gbenegas/software/mambaforge/envs/gpn/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /scratch/users/gbenegas/software/mambaforge/envs/gpn/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /scratch/users/gbenegas/software/mambaforge/envs/gpn/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /scratch/users/gbenegas/software/mambaforge/envs/gpn/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
