# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
model_metadata = pd.read_csv("../../config/models.csv")
palette = model_metadata.set_index("description")["color"].to_dict()
model_renaming = model_metadata.set_index("name")["description"].to_dict()
model_metadata
# Out:
#                      name   description color
# 0                    CADD          CADD    C0
# 1                 GPN-MSA       GPN-MSA    C1
# 2                  Borzoi        Borzoi    C2
# 3                Enformer      Enformer    C3
# 4                     GPN  gLM-Promoter    C4
# 5   NucleotideTransformer            NT    C5
# 6                HyenaDNA      HyenaDNA    C6
# 7                Caduceus      Caduceus    C7
# 8     CADD+GPN-MSA+Borzoi      Ensemble    C8
# 9                     Sei           Sei    C9
# 10              GPN_final  gLM-Promoter    C4

# %%
dataset_renaming = {
    "complex_traits_matched_9": "Complex traits",
}

subset_renaming = {
    "yes_eqtl_overlap": "eQTL",
    "no_eqtl_overlap": "Non-eQTL",
}

# %%
datasets = [
    "complex_traits_matched_9",
]

subsets = [
    "yes_eqtl_overlap",
    "no_eqtl_overlap",
]

modalities = [
    "Zero-shot",
    "Linear probing",
]

models = [
    "Borzoi",
    "GPN-MSA",
    "CADD",
    "CADD+GPN-MSA+Borzoi",
]

metric = "AUPRC"

def get_model_path(model, modality, dataset, subset):
    if modality == "Linear probing":
        predictor = f"{model}.LogisticRegression.chrom.subset_from_all"
    elif modality == "Zero-shot":
        if model == "CADD":
            predictor = "CADD.plus.RawScore"
        elif model in ["Enformer", "Borzoi"]:
            predictor = f"{model}_L2_L2.plus.all"
        else:
            if "mendelian" in dataset:
                llr_version = "LLR"
                sign = "minus"
            elif "complex" in dataset:
                llr_version = "absLLR"
                sign = "plus"
            predictor = f"{model}_{llr_version}.{sign}.score"
    return f"../../results/dataset/{dataset}/{metric}_by_chrom_weighted_average/{subset}/{predictor}.csv"

# %%
rows = []
for dataset in datasets:
    for subset in subsets:
        for modality in modalities:
            for model in models:
                if modality == "Zero-shot" and "+" in model: continue
                model_for_path = model
                if "mendelian" in dataset and model == "CADD+GPN-MSA+Borzoi":
                    model_for_path = "CADD+GPN-MSA_LLR+Borzoi_L2_L2"
                path = get_model_path(
                    model_for_path,
                    modality,
                    dataset,
                    subset
                )
                df = pd.read_csv(path).iloc[0]
                rows.append([
                    dataset_renaming.get(dataset, dataset),
                    subset_renaming.get(subset, subset),
                    modality,
                    model_renaming.get(model, model),
                    df["score"],
                    df["se"],
                ])
df = pd.DataFrame(rows, columns=["dataset", "subset", "modality", "model", "score", "se"])
df
# Out:
#            dataset    subset        modality     model     score        se
# 0   Complex traits      eQTL       Zero-shot    Borzoi  0.523975  0.032275
# 1   Complex traits      eQTL       Zero-shot   GPN-MSA  0.398669  0.045167
# 2   Complex traits      eQTL       Zero-shot      CADD  0.381481  0.041639
# 3   Complex traits      eQTL  Linear probing    Borzoi  0.524271  0.038609
# 4   Complex traits      eQTL  Linear probing   GPN-MSA  0.337369  0.036741
# 5   Complex traits      eQTL  Linear probing      CADD  0.396907  0.045781
# 6   Complex traits      eQTL  Linear probing  Ensemble  0.523115  0.039447
# 7   Complex traits  Non-eQTL       Zero-shot    Borzoi  0.213626  0.009441
# 8   Complex traits  Non-eQTL       Zero-shot   GPN-MSA  0.216250  0.010139
# 9   Complex traits  Non-eQTL       Zero-shot      CADD  0.244698  0.011060
# 10  Complex traits  Non-eQTL  Linear probing    Borzoi  0.280354  0.013136
# 11  Complex traits  Non-eQTL  Linear probing   GPN-MSA  0.272227  0.012976
# 12  Complex traits  Non-eQTL  Linear probing      CADD  0.283123  0.012851
# 13  Complex traits  Non-eQTL  Linear probing  Ensemble  0.351630  0.014942

# %%
def best_modality(df):
    res = df.sort_values("score", ascending=False).iloc[0]
    return res[["score", "se"]]

df = df.groupby(["dataset", "subset", "model"], sort=False).apply(best_modality).reset_index()
df
# Out:
#           dataset    subset     model     score        se
# 0  Complex traits      eQTL    Borzoi  0.524271  0.038609
# 1  Complex traits      eQTL   GPN-MSA  0.398669  0.045167
# 2  Complex traits      eQTL      CADD  0.396907  0.045781
# 3  Complex traits      eQTL  Ensemble  0.523115  0.039447
# 4  Complex traits  Non-eQTL    Borzoi  0.280354  0.013136
# 5  Complex traits  Non-eQTL   GPN-MSA  0.272227  0.012976
# 6  Complex traits  Non-eQTL      CADD  0.283123  0.012851
# 7  Complex traits  Non-eQTL  Ensemble  0.351630  0.014942

# %%
g = sns.FacetGrid(
    data=df.rename(columns={"score": "AUPRC"}),
    col="dataset",
    row="subset",
    margin_titles=True,
    #sharex="col",
    sharex=True,
    sharey=False,
    height=1.3,
    aspect=1.5,
)

def my_boxplot(data, **kwargs):
    data = data.sort_values("AUPRC", ascending=False)
    ax = plt.gca()
    g = sns.barplot(
        data=data,
        y="model",
        x="AUPRC",
        ax=ax,
        palette=palette,
    )
    bar_height = g.patches[0].get_height()
    y_coords = sorted([bar.get_y() + bar_height / 2 for bar in g.patches])
    ax.errorbar(
        x=data["AUPRC"],
        y=y_coords,
        xerr=data["se"],
        fmt='none',
        color="black",
    )

g.map_dataframe(my_boxplot)
g.figure.subplots_adjust(hspace=0)

g.set(
    ylabel="",
    xlim=0.1,
)
g.set_titles(
    col_template="{col_name}", row_template="{row_name}",
    fontweight="bold",
    #size=12,
)
g.tight_layout()
plt.savefig("../../results/plots/performance_eqtl_overlap.pdf", bbox_inches="tight")
# Out:
# /scratch/users/gbenegas/software/mambaforge/envs/gpn/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /scratch/users/gbenegas/software/mambaforge/envs/gpn/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /scratch/users/gbenegas/software/mambaforge/envs/gpn/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /scratch/users/gbenegas/software/mambaforge/envs/gpn/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /scratch/users/gbenegas/software/mambaforge/envs/gpn/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /scratch/users/gbenegas/software/mambaforge/envs/gpn/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /scratch/users/gbenegas/software/mambaforge/envs/gpn/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /scratch/users/gbenegas/software/mambaforge/envs/gpn/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
dataset = "complex_traits_matched_9"
V = pd.read_parquet(f"../../results/dataset/{dataset}/test.parquet").query("label")
V
# Out:
#       chrom       pos ref alt       pip              trait  label       maf  \
# 8         1   2293397   G   A  0.999932             Height   True  0.370570
# 17        1   3080038   T   C  0.999895    MCH,MCV,Plt,RBC   True  0.232720
# 26        1   3774964   A   G  0.999973  Hb,HbA1c,MCHC,RBC   True  0.230570
# 60        1   9181780   G   A  1.000000           AST,Mono   True  0.074322
# 61        1   9295877   G   T  0.993319                DVT   True  0.265060
# ...     ...       ...  ..  ..       ...                ...    ...       ...
# 11354    22  45969257   G   A  0.999905               eBMD   True  0.002641
# 11355    22  45979731   C   T  0.980260               eBMD   True  0.167140
# 11359    22  46219479   G   A  0.945802                 BW   True  0.128710
# 11372    22  47990921   C   T  0.997536                BMI   True  0.437610
# 11393    22  50190508   G   A  1.000000                Plt   True  0.072852
#
#        ld_score                         consequence  tss_dist  \
# 8       32.3020                                dELS     65077
# 17      31.6060                                dELS     10826
# 26      95.3170                                dELS      2138
# 60      35.4720  non_coding_transcript_exon_variant     52677
# 61      46.3070                                dELS      1348
# ...         ...                                 ...       ...
# 11354    9.5349                                dELS      3457
# 11355   37.7760                                dELS      2568
# 11359  164.8500                          dELS_flank     28805
# 11372   53.5140                      intron_variant    498631
# 11393   57.9700                                 PLS        89
#
#                                 match_group
# 8                                    dELS_0
# 17                                   dELS_1
# 26                                   dELS_2
# 60     non_coding_transcript_exon_variant_0
# 61                                   dELS_3
# ...                                     ...
# 11354                              dELS_207
# 11355                              dELS_208
# 11359                        dELS_flank_108
# 11372                    intron_variant_124
# 11393                                PLS_21
#
# [1140 rows x 12 columns]

# %%
eqtl = pd.read_parquet("../../results/dataset/complex_traits_matched_9/subset/yes_eqtl_overlap.parquet")
eqtl["eqtl"] = True
eqtl
# Out:
#      chrom       pos ref alt  eqtl
# 0        1    867476   C   T  True
# 1        1    868052   T   C  True
# 2        1    868635   A   G  True
# 3        1    870176   T   A  True
# 4        1   3690596   G   A  True
# ...    ...       ...  ..  ..   ...
# 1025    22  49967092   T   G  True
# 1026    22  50190508   G   A  True
# 1027    22  50343347   G   C  True
# 1028    22  50368376   T   C  True
# 1029    22  50783672   G   T  True
#
# [1030 rows x 5 columns]

# %%
disease = pd.read_parquet("../../results/dataset/complex_traits_matched_9/subset/disease.parquet")
disease["disease"] = True
disease
# Out:
#     chrom       pos ref alt  disease
# 0       1   1989803   A   G     True
# 1       1   2869701   G   T     True
# 2       1   2878207   G   C     True
# 3       1   3904770   G   A     True
# 4       1   4725471   C   T     True
# ..    ...       ...  ..  ..      ...
# 525    22  44812046   G   A     True
# 526    22  45247338   G   A     True
# 527    22  48633512   G   C     True
# 528    22  48705151   G   C     True
# 529    22  50006148   A   G     True
#
# [530 rows x 5 columns]

# %%
V = V.merge(eqtl, on=["chrom", "pos", "ref", "alt"], how="left")
V.eqtl = V.eqtl.fillna(False)
V = V.merge(disease, on=["chrom", "pos", "ref", "alt"], how="left")
V.disease = V.disease.fillna(False)
V
# Out:
#      chrom       pos ref alt       pip              trait  label       maf  \
# 0        1   2293397   G   A  0.999932             Height   True  0.370570
# 1        1   3080038   T   C  0.999895    MCH,MCV,Plt,RBC   True  0.232720
# 2        1   3774964   A   G  0.999973  Hb,HbA1c,MCHC,RBC   True  0.230570
# 3        1   9181780   G   A  1.000000           AST,Mono   True  0.074322
# 4        1   9295877   G   T  0.993319                DVT   True  0.265060
# ...    ...       ...  ..  ..       ...                ...    ...       ...
# 1135    22  45969257   G   A  0.999905               eBMD   True  0.002641
# 1136    22  45979731   C   T  0.980260               eBMD   True  0.167140
# 1137    22  46219479   G   A  0.945802                 BW   True  0.128710
# 1138    22  47990921   C   T  0.997536                BMI   True  0.437610
# 1139    22  50190508   G   A  1.000000                Plt   True  0.072852
#
#       ld_score                         consequence  tss_dist  \
# 0      32.3020                                dELS     65077
# 1      31.6060                                dELS     10826
# 2      95.3170                                dELS      2138
# 3      35.4720  non_coding_transcript_exon_variant     52677
# 4      46.3070                                dELS      1348
# ...        ...                                 ...       ...
# 1135    9.5349                                dELS      3457
# 1136   37.7760                                dELS      2568
# 1137  164.8500                          dELS_flank     28805
# 1138   53.5140                      intron_variant    498631
# 1139   57.9700                                 PLS        89
#
#                                match_group   eqtl  disease
# 0                                   dELS_0  False    False
# 1                                   dELS_1  False    False
# 2                                   dELS_2   True    False
# 3     non_coding_transcript_exon_variant_0   True    False
# 4                                   dELS_3  False     True
# ...                                    ...    ...      ...
# 1135                              dELS_207  False    False
# 1136                              dELS_208  False    False
# 1137                        dELS_flank_108  False    False
# 1138                    intron_variant_124  False    False
# 1139                                PLS_21   True    False
#
# [1140 rows x 14 columns]

# %%
V.groupby(["eqtl", "disease"]).size()
# Out:
# eqtl   disease
# False  False      990
#        True        47
# True   False       97
#        True         6
# dtype: int64

# %%
47 / 990
# Out:
# 0.047474747474747475

# %%
6/ 97
# Out:
# 0.061855670103092786

# %%
V.groupby("eqtl").tss_dist.mean()
# Out:
# eqtl
# False    59123.104147
# True     23911.291262
# Name: tss_dist, dtype: Float64

# %%
other_consequences = [
    "missense_variant",
    "non_coding_transcript_exon_variant",
    "3_prime_UTR_variant",
    "5_prime_UTR_variant",
]
V.loc[~V.consequence.isin(other_consequences), "consequence"] = "non-exonic"

# %%
V.groupby("eqtl").consequence.value_counts(normalize=True)
# Out:
# eqtl   consequence
# False  non-exonic                            0.876567
#        non_coding_transcript_exon_variant    0.056895
#        3_prime_UTR_variant                   0.040501
#        5_prime_UTR_variant                   0.026037
# True   non-exonic                            0.660194
#        5_prime_UTR_variant                   0.145631
#        3_prime_UTR_variant                   0.097087
#        non_coding_transcript_exon_variant    0.097087
# Name: proportion, dtype: float64

# %%
V[V.consequence == "non-exonic"].groupby("eqtl").tss_dist.mean()
# Out:
# eqtl
# False    63269.114411
# True     29930.308824
# Name: tss_dist, dtype: Float64

# %%
V[V.consequence == "non-exonic"].groupby("eqtl").tss_dist.median()
# Out:
# eqtl
# False    18405.0
# True      6712.5
# Name: tss_dist, dtype: Float64

# %%
df = V.groupby("eqtl").consequence.value_counts(normalize=True).unstack().fillna(0)
df
# Out:
# consequence  3_prime_UTR_variant  5_prime_UTR_variant  non-exonic  \
# eqtl
# False                   0.040501             0.026037    0.876567
# True                    0.097087             0.145631    0.660194
#
# consequence  non_coding_transcript_exon_variant
# eqtl
# False                                  0.056895
# True                                   0.097087

# %%
df2 = V[V.consequence == "non-exonic"]
df2
# Out:
#      chrom       pos ref alt       pip              trait  label       maf  \
# 0        1   2293397   G   A  0.999932             Height   True  0.370570
# 1        1   3080038   T   C  0.999895    MCH,MCV,Plt,RBC   True  0.232720
# 2        1   3774964   A   G  0.999973  Hb,HbA1c,MCHC,RBC   True  0.230570
# 4        1   9295877   G   T  0.993319                DVT   True  0.265060
# 6        1  10630891   C   T  0.985187               eGFR   True  0.059295
# ...    ...       ...  ..  ..       ...                ...    ...       ...
# 1135    22  45969257   G   A  0.999905               eBMD   True  0.002641
# 1136    22  45979731   C   T  0.980260               eBMD   True  0.167140
# 1137    22  46219479   G   A  0.945802                 BW   True  0.128710
# 1138    22  47990921   C   T  0.997536                BMI   True  0.437610
# 1139    22  50190508   G   A  1.000000                Plt   True  0.072852
#
#       ld_score consequence  tss_dist         match_group   eqtl  disease
# 0      32.3020  non-exonic     65077              dELS_0  False    False
# 1      31.6060  non-exonic     10826              dELS_1  False    False
# 2      95.3170  non-exonic      2138              dELS_2   True    False
# 4      46.3070  non-exonic      1348              dELS_3  False     True
# 6      52.9340  non-exonic     14184              dELS_4  False    False
# ...        ...         ...       ...                 ...    ...      ...
# 1135    9.5349  non-exonic      3457            dELS_207  False    False
# 1136   37.7760  non-exonic      2568            dELS_208  False    False
# 1137  164.8500  non-exonic     28805      dELS_flank_108  False    False
# 1138   53.5140  non-exonic    498631  intron_variant_124  False    False
# 1139   57.9700  non-exonic        89              PLS_21   True    False
#
# [977 rows x 14 columns]

# %%
sns.histplot(df2, x="tss_dist", hue="eqtl", element="step", common_norm=False, stat="density")
# Out:
# /scratch/users/gbenegas/software/mambaforge/envs/gpn/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /scratch/users/gbenegas/software/mambaforge/envs/gpn/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /scratch/users/gbenegas/software/mambaforge/envs/gpn/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /scratch/users/gbenegas/software/mambaforge/envs/gpn/lib/python3.11/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /scratch/users/gbenegas/software/mambaforge/envs/gpn/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='tss_dist', ylabel='Density'>

# %%
from scipy.stats import mannwhitneyu
mannwhitneyu(
    df2.query("eqtl").tss_dist.astype(int),
    df2.query("~eqtl").tss_dist.astype(int),
    alternative="less",
)
# Out:
# MannwhitneyuResult(statistic=23309.0, pvalue=0.0003565011929665489)

# %%
V["exonic"] = V.consequence != "non-exonic"
df = V.groupby("eqtl").exonic.value_counts()
df
# Out:
# eqtl   exonic
# False  False     909
#        True      128
# True   False      68
#        True       35
# Name: count, dtype: int64

# %%
from scipy.stats import fisher_exact

fisher_exact(df.values.reshape(2, 2), alternative="greater")
# Out:
# SignificanceResult(statistic=3.655215992647059, pvalue=8.189027716001461e-08)

# %%
df.values.reshape(2, 2)
# Out:
# array([[909, 128],
#        [ 68,  35]])
