# %%
import numpy as np
import pandas as pd

# %%
model_metadata = pd.read_csv("../../config/models.csv")
palette = model_metadata.set_index("description")["color"].to_dict()
model_renaming = model_metadata.set_index("name")["description"].to_dict()
model_metadata
# Out:
#                     name   description color
# 0                   CADD          CADD    C0
# 1                GPN-MSA       GPN-MSA    C1
# 2                 Borzoi        Borzoi    C2
# 3               Enformer      Enformer    C3
# 4                    GPN  gLM-Promoter    C4
# 5  NucleotideTransformer            NT    C5
# 6               HyenaDNA      HyenaDNA    C6
# 7               Caduceus      Caduceus    C7
# 8    CADD+GPN-MSA+Borzoi      Ensemble    C8

# %%
mendelian_traits = (
    pd.read_csv("../../config/omim/filtered_traits.txt", header=None, dtype=str)
    .values.ravel().tolist()
)
complex_traits = (
    pd.read_csv("../../config/gwas/independent_traits_filtered.csv", header=None)
    .values.ravel().tolist()
)
#complex_traits_n30 = (
#    pd.read_csv("../../config/gwas/independent_traits_filtered_n30.csv", header=None)
#    .values.ravel().tolist()
#)

complex_trait_renaming = pd.read_csv(
    "../../results/gwas/raw/release1.1/UKBB_94traits_release1.traits", sep="\t",
    usecols=["trait", "description"]
).set_index("trait")["description"].to_dict()

mendelian_trait_renaming = {
    "600886": "Hyperferritinemia",
    "613985": "Beta-thalassemia",
    "614743": "Pulmonary fibrosis",
    "306900": "Hemophilia B",
    "250250": "Cartilage-hair hypoplasia",
    "174500": "Preaxial polydactyly II",
    "143890": "Hypercholesterolemia-1",
    "210710": "Dwarfism (MOPD1)",
}

trait_renaming = {**complex_trait_renaming, **mendelian_trait_renaming}

dataset_renaming = {
    "mendelian_traits_matched_9": "Mendelian traits",
    "complex_traits_matched_9": "Complex traits",
}

subset_renaming = trait_renaming

# %%
datasets = [
    "mendelian_traits_matched_9",
    "complex_traits_matched_9",
]

subsets = {
    "mendelian_traits_matched_9": mendelian_traits,
    "complex_traits_matched_9": complex_traits,
}

#linear_probing_subsets = [f"non_coding_AND_{trait}" for trait in complex_traits_n30]

modalities = [
    "Zero-shot",
    "Linear probing",
]

models = [
    "Borzoi",
    "GPN-MSA",
    "CADD",
    "CADD+GPN-MSA+Borzoi",
]

def get_model_path(model, modality, dataset, subset):
    if modality == "Linear probing":
        predictor = f"{model}.LogisticRegression.chrom.subset_from_all"
    elif modality == "Zero-shot":
        if model == "CADD":
            predictor = "CADD.plus.RawScore"
        elif model in ["Enformer", "Borzoi"]:
            predictor = f"{model}_L2_L2.plus.all"
        else:
            if "mendelian" in dataset:
                llr_version = "LLR"
                sign = "minus"
            elif "complex" in dataset:
                llr_version = "absLLR"
                sign = "plus"
            predictor = f"{model}_{llr_version}.{sign}.score"
    return f"../../results/dataset/{dataset}/metrics_by_chrom_weighted_average/{subset}/{predictor}.csv"

# %%
rows = []
for dataset in datasets:
    for subset in subsets[dataset]:
        for modality in modalities:
            for model in models:
                if modality == "Zero-shot" and "+" in model: continue
                model_for_path = model
                if "mendelian" in dataset and model == "CADD+GPN-MSA+Borzoi":
                    model_for_path = "CADD+GPN-MSA_LLR+Borzoi_L2_L2"
                path = get_model_path(model_for_path, modality, dataset, subset)
                df = pd.read_csv(path).iloc[0]
                rows.append([
                    dataset_renaming.get(dataset, dataset),
                    subset_renaming.get(subset, subset),
                    modality,
                    model_renaming.get(model, model),
                    df["score"],
                    df["se"],
                ])
df = pd.DataFrame(rows, columns=["dataset", "subset", "modality", "model", "score", "se"])
df
# Out:
#               dataset                 subset        modality     model  \
# 0    Mendelian traits      Hyperferritinemia       Zero-shot    Borzoi
# 1    Mendelian traits      Hyperferritinemia       Zero-shot   GPN-MSA
# 2    Mendelian traits      Hyperferritinemia       Zero-shot      CADD
# 3    Mendelian traits      Hyperferritinemia  Linear probing    Borzoi
# 4    Mendelian traits      Hyperferritinemia  Linear probing   GPN-MSA
# ..                ...                    ...             ...       ...
# 177    Complex traits  Blood clot in the leg       Zero-shot      CADD
# 178    Complex traits  Blood clot in the leg  Linear probing    Borzoi
# 179    Complex traits  Blood clot in the leg  Linear probing   GPN-MSA
# 180    Complex traits  Blood clot in the leg  Linear probing      CADD
# 181    Complex traits  Blood clot in the leg  Linear probing  Ensemble
#
#         score            se
# 0    0.131633  2.776946e-17
# 1    0.964481  0.000000e+00
# 2    0.956952  2.221557e-16
# 3    0.314713  0.000000e+00
# 4    0.964731  0.000000e+00
# ..        ...           ...
# 177  0.481151  9.997103e-02
# 178  0.573701  7.382674e-02
# 179  0.487698  9.540585e-02
# 180  0.498392  1.041968e-01
# 181  0.565079  7.637671e-02
#
# [182 rows x 6 columns]

# %%
def best_modality(df):
    res = df.sort_values("score", ascending=False).iloc[0]
    return res[["score", "se"]]

df = df.groupby(["dataset", "subset", "model"], sort=False).apply(best_modality).reset_index()
df
# Out:
#               dataset                 subset     model     score            se
# 0    Mendelian traits      Hyperferritinemia    Borzoi  0.314713  0.000000e+00
# 1    Mendelian traits      Hyperferritinemia   GPN-MSA  0.964731  0.000000e+00
# 2    Mendelian traits      Hyperferritinemia      CADD  0.980622  1.110779e-16
# 3    Mendelian traits      Hyperferritinemia  Ensemble  0.985000  0.000000e+00
# 4    Mendelian traits       Beta-thalassemia    Borzoi  0.926512  2.221557e-16
# ..                ...                    ...       ...       ...           ...
# 99     Complex traits         Balding Type 4  Ensemble  0.625071  7.998706e-02
# 100    Complex traits  Blood clot in the leg    Borzoi  0.573701  7.382674e-02
# 101    Complex traits  Blood clot in the leg   GPN-MSA  0.550735  1.096933e-01
# 102    Complex traits  Blood clot in the leg      CADD  0.498392  1.041968e-01
# 103    Complex traits  Blood clot in the leg  Ensemble  0.565079  7.637671e-02
#
# [104 rows x 5 columns]

# %%
def format_score(x):
    return (x * 100).round().astype(int).apply(lambda y: f"{y:02d}")

def format_se(x):
    assert (x * 100).max() < 100
    return (x * 100).round().astype(int).apply(lambda y: f"{y:02d}")

#df["value"] = format_score(df.score) + "$\pm$" + format_se(df.se)
#df["value"] = format_score(df.score)
#df["value"] = df.score.apply(lambda x: f"{x:.2f}") + "$\pm$" + df.se.apply(lambda x: f"{x:.2f}")
df["value"] = df.score.apply(lambda x: f"{x:.3f}")
df
# Out:
#               dataset                 subset     model     score  \
# 0    Mendelian traits      Hyperferritinemia    Borzoi  0.314713
# 1    Mendelian traits      Hyperferritinemia   GPN-MSA  0.964731
# 2    Mendelian traits      Hyperferritinemia      CADD  0.980622
# 3    Mendelian traits      Hyperferritinemia  Ensemble  0.985000
# 4    Mendelian traits       Beta-thalassemia    Borzoi  0.926512
# ..                ...                    ...       ...       ...
# 99     Complex traits         Balding Type 4  Ensemble  0.625071
# 100    Complex traits  Blood clot in the leg    Borzoi  0.573701
# 101    Complex traits  Blood clot in the leg   GPN-MSA  0.550735
# 102    Complex traits  Blood clot in the leg      CADD  0.498392
# 103    Complex traits  Blood clot in the leg  Ensemble  0.565079
#
#                se  value
# 0    0.000000e+00  0.315
# 1    0.000000e+00  0.965
# 2    1.110779e-16  0.981
# 3    0.000000e+00  0.985
# 4    2.221557e-16  0.927
# ..            ...    ...
# 99   7.998706e-02  0.625
# 100  7.382674e-02  0.574
# 101  1.096933e-01  0.551
# 102  1.041968e-01  0.498
# 103  7.637671e-02  0.565
#
# [104 rows x 6 columns]

# %%
df = df.pivot_table(
    columns=[
        #"modality",
        "model",
    ],
    index=[
        #"dataset",
        "subset",
    ],
    values="value",
    aggfunc="first", sort=False,
)
df = df.fillna("-")
df
# Out:
# model                                            Borzoi GPN-MSA   CADD  \
# subset
# Hyperferritinemia                                 0.315   0.965  0.981
# Beta-thalassemia                                  0.927   0.796  0.926
# Pulmonary fibrosis                                0.564   0.948  1.000
# Hemophilia B                                      0.914   0.709  1.000
# Cartilage-hair hypoplasia                         0.594   0.987  0.923
# Preaxial polydactyly II                           0.546   0.959  0.969
# Hypercholesterolemia-1                            0.844   0.974  0.887
# Dwarfism (MOPD1)                                  0.484   1.000  1.000
# Adult height                                      0.292   0.383  0.407
# Platelet count                                    0.426   0.309  0.397
# Estimated heel bone mineral density               0.308   0.432  0.422
# Mean corpuscular volume                           0.434   0.319  0.391
# Monocyte count                                    0.561   0.404  0.375
# Hemoglobin A1c                                    0.475   0.375  0.426
# Albumin/Globulin ratio                            0.455   0.431  0.516
# High density lipoprotein cholesterol              0.521   0.362  0.425
# Estimated glomerular filtration rate (cystain C)  0.457   0.456  0.421
# Alkaline phosphatase                              0.492   0.292  0.352
# Gamma-glutamyl transferase                        0.515   0.382  0.460
# FEV1/FVC ratio                                    0.430   0.494  0.505
# Pluse pressure                                    0.457   0.435  0.420
# Calcium                                           0.468   0.433  0.425
# Albumin                                           0.615   0.544  0.480
# Body mass index                                   0.344   0.514  0.436
# Balding Type 4                                    0.459   0.536  0.414
# Blood clot in the leg                             0.574   0.551  0.498
#
# model                                            Ensemble
# subset
# Hyperferritinemia                                   0.985
# Beta-thalassemia                                    0.955
# Pulmonary fibrosis                                  1.000
# Hemophilia B                                        0.991
# Cartilage-hair hypoplasia                           0.918
# Preaxial polydactyly II                             0.967
# Hypercholesterolemia-1                              0.938
# Dwarfism (MOPD1)                                    1.000
# Adult height                                        0.339
# Platelet count                                      0.478
# Estimated heel bone mineral density                 0.406
# Mean corpuscular volume                             0.454
# Monocyte count                                      0.535
# Hemoglobin A1c                                      0.517
# Albumin/Globulin ratio                              0.559
# High density lipoprotein cholesterol                0.554
# Estimated glomerular filtration rate (cystain C)    0.470
# Alkaline phosphatase                                0.446
# Gamma-glutamyl transferase                          0.527
# FEV1/FVC ratio                                      0.487
# Pluse pressure                                      0.489
# Calcium                                             0.408
# Albumin                                             0.602
# Body mass index                                     0.499
# Balding Type 4                                      0.625
# Blood clot in the leg                               0.565

# %%
def boldface_best_model(x):
    threshold = 0.01
    y = x.astype(float)
    best_score = y.max()
    best_models = y[(best_score - y) < threshold].index
    res = x.copy()
    for best_model in best_models:
        res[best_model] = r"\textbf{" + res[best_model] + r"}"
    return res

df = df.apply(boldface_best_model, axis=1)
df
# Out:
# model                                                     Borzoi  \
# subset
# Hyperferritinemia                                          0.315
# Beta-thalassemia                                           0.927
# Pulmonary fibrosis                                         0.564
# Hemophilia B                                               0.914
# Cartilage-hair hypoplasia                                  0.594
# Preaxial polydactyly II                                    0.546
# Hypercholesterolemia-1                                     0.844
# Dwarfism (MOPD1)                                           0.484
# Adult height                                               0.292
# Platelet count                                             0.426
# Estimated heel bone mineral density                        0.308
# Mean corpuscular volume                                    0.434
# Monocyte count                                    \textbf{0.561}
# Hemoglobin A1c                                             0.475
# Albumin/Globulin ratio                                     0.455
# High density lipoprotein cholesterol                       0.521
# Estimated glomerular filtration rate (cystain C)           0.457
# Alkaline phosphatase                              \textbf{0.492}
# Gamma-glutamyl transferase                                 0.515
# FEV1/FVC ratio                                             0.430
# Pluse pressure                                             0.457
# Calcium                                           \textbf{0.468}
# Albumin                                           \textbf{0.615}
# Body mass index                                            0.344
# Balding Type 4                                             0.459
# Blood clot in the leg                             \textbf{0.574}
#
# model                                                    GPN-MSA  \
# subset
# Hyperferritinemia                                          0.965
# Beta-thalassemia                                           0.796
# Pulmonary fibrosis                                         0.948
# Hemophilia B                                               0.709
# Cartilage-hair hypoplasia                         \textbf{0.987}
# Preaxial polydactyly II                                    0.959
# Hypercholesterolemia-1                            \textbf{0.974}
# Dwarfism (MOPD1)                                  \textbf{1.000}
# Adult height                                               0.383
# Platelet count                                             0.309
# Estimated heel bone mineral density               \textbf{0.432}
# Mean corpuscular volume                                    0.319
# Monocyte count                                             0.404
# Hemoglobin A1c                                             0.375
# Albumin/Globulin ratio                                     0.431
# High density lipoprotein cholesterol                       0.362
# Estimated glomerular filtration rate (cystain C)           0.456
# Alkaline phosphatase                                       0.292
# Gamma-glutamyl transferase                                 0.382
# FEV1/FVC ratio                                             0.494
# Pluse pressure                                             0.435
# Calcium                                                    0.433
# Albumin                                                    0.544
# Body mass index                                   \textbf{0.514}
# Balding Type 4                                             0.536
# Blood clot in the leg                                      0.551
#
# model                                                       CADD  \
# subset
# Hyperferritinemia                                 \textbf{0.981}
# Beta-thalassemia                                           0.926
# Pulmonary fibrosis                                \textbf{1.000}
# Hemophilia B                                      \textbf{1.000}
# Cartilage-hair hypoplasia                                  0.923
# Preaxial polydactyly II                           \textbf{0.969}
# Hypercholesterolemia-1                                     0.887
# Dwarfism (MOPD1)                                  \textbf{1.000}
# Adult height                                      \textbf{0.407}
# Platelet count                                             0.397
# Estimated heel bone mineral density                        0.422
# Mean corpuscular volume                                    0.391
# Monocyte count                                             0.375
# Hemoglobin A1c                                             0.426
# Albumin/Globulin ratio                                     0.516
# High density lipoprotein cholesterol                       0.425
# Estimated glomerular filtration rate (cystain C)           0.421
# Alkaline phosphatase                                       0.352
# Gamma-glutamyl transferase                                 0.460
# FEV1/FVC ratio                                    \textbf{0.505}
# Pluse pressure                                             0.420
# Calcium                                                    0.425
# Albumin                                                    0.480
# Body mass index                                            0.436
# Balding Type 4                                             0.414
# Blood clot in the leg                                      0.498
#
# model                                                   Ensemble
# subset
# Hyperferritinemia                                 \textbf{0.985}
# Beta-thalassemia                                  \textbf{0.955}
# Pulmonary fibrosis                                \textbf{1.000}
# Hemophilia B                                      \textbf{0.991}
# Cartilage-hair hypoplasia                                  0.918
# Preaxial polydactyly II                           \textbf{0.967}
# Hypercholesterolemia-1                                     0.938
# Dwarfism (MOPD1)                                  \textbf{1.000}
# Adult height                                               0.339
# Platelet count                                    \textbf{0.478}
# Estimated heel bone mineral density                        0.406
# Mean corpuscular volume                           \textbf{0.454}
# Monocyte count                                             0.535
# Hemoglobin A1c                                    \textbf{0.517}
# Albumin/Globulin ratio                            \textbf{0.559}
# High density lipoprotein cholesterol              \textbf{0.554}
# Estimated glomerular filtration rate (cystain C)  \textbf{0.470}
# Alkaline phosphatase                                       0.446
# Gamma-glutamyl transferase                        \textbf{0.527}
# FEV1/FVC ratio                                             0.487
# Pluse pressure                                    \textbf{0.489}
# Calcium                                                    0.408
# Albumin                                                    0.602
# Body mass index                                            0.499
# Balding Type 4                                    \textbf{0.625}
# Blood clot in the leg                             \textbf{0.565}

# %%
#df.index.names = [None, None]
df.index.name = None
#df.columns.names = [None, None]
df.columns.name = None

# %%
print(df.to_latex(multicolumn_format='c', escape=False))
# Out:
# \begin{tabular}{lllll}
# \toprule
#  & Borzoi & GPN-MSA & CADD & Ensemble \\
# \midrule
# Hyperferritinemia & 0.315 & 0.965 & \textbf{0.981} & \textbf{0.985} \\
# Beta-thalassemia & 0.927 & 0.796 & 0.926 & \textbf{0.955} \\
# Pulmonary fibrosis & 0.564 & 0.948 & \textbf{1.000} & \textbf{1.000} \\
# Hemophilia B & 0.914 & 0.709 & \textbf{1.000} & \textbf{0.991} \\
# Cartilage-hair hypoplasia & 0.594 & \textbf{0.987} & 0.923 & 0.918 \\
# Preaxial polydactyly II & 0.546 & 0.959 & \textbf{0.969} & \textbf{0.967} \\
# Hypercholesterolemia-1 & 0.844 & \textbf{0.974} & 0.887 & 0.938 \\
# Dwarfism (MOPD1) & 0.484 & \textbf{1.000} & \textbf{1.000} & \textbf{1.000} \\
# Adult height & 0.292 & 0.383 & \textbf{0.407} & 0.339 \\
# Platelet count & 0.426 & 0.309 & 0.397 & \textbf{0.478} \\
# Estimated heel bone mineral density & 0.308 & \textbf{0.432} & 0.422 & 0.406 \\
# Mean corpuscular volume & 0.434 & 0.319 & 0.391 & \textbf{0.454} \\
# Monocyte count & \textbf{0.561} & 0.404 & 0.375 & 0.535 \\
# Hemoglobin A1c & 0.475 & 0.375 & 0.426 & \textbf{0.517} \\
# Albumin/Globulin ratio & 0.455 & 0.431 & 0.516 & \textbf{0.559} \\
# High density lipoprotein cholesterol & 0.521 & 0.362 & 0.425 & \textbf{0.554} \\
# Estimated glomerular filtration rate (cystain C) & 0.457 & 0.456 & 0.421 & \textbf{0.470} \\
# Alkaline phosphatase & \textbf{0.492} & 0.292 & 0.352 & 0.446 \\
# Gamma-glutamyl transferase & 0.515 & 0.382 & 0.460 & \textbf{0.527} \\
# FEV1/FVC ratio & 0.430 & 0.494 & \textbf{0.505} & 0.487 \\
# Pluse pressure & 0.457 & 0.435 & 0.420 & \textbf{0.489} \\
# Calcium & \textbf{0.468} & 0.433 & 0.425 & 0.408 \\
# Albumin & \textbf{0.615} & 0.544 & 0.480 & 0.602 \\
# Body mass index & 0.344 & \textbf{0.514} & 0.436 & 0.499 \\
# Balding Type 4 & 0.459 & 0.536 & 0.414 & \textbf{0.625} \\
# Blood clot in the leg & \textbf{0.574} & 0.551 & 0.498 & \textbf{0.565} \\
# \bottomrule
# \end{tabular}
